# %% [markdown]
# ## 聚类与统计策略分析

# %%
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn')
# %matplotlib inline

# %% [markdown]
# ## 导入数据

# %%
raw = pd.read_csv('data.csv',index_col=0, parse_dates=True).dropna()
symbol = 'EUR='
data = pd.DataFrame(raw[symbol])
data['returns'] = np.log(data / data.shift(1))
data.dropna(inplace=True)
data['direction'] = np.sign(data['returns']).astype(int)

# %%
lags = 2
def create_lags(data):
    global cols
    cols = []
    for lag in range(1,lags+1):
        col = 'lag_{}'.format(lag)
        data[col] = data['returns'].shift(lag)
        cols.append(col)
create_lags(data)
data.dropna(inplace=True)
data.head()
# Out:
#               EUR=   returns  direction     lag_1     lag_2
# Date
# 2010-01-07  1.4318 -0.006544         -1  0.003058 -0.002988
# 2010-01-08  1.4412  0.006544          1 -0.006544  0.003058
# 2010-01-11  1.4513  0.006984          1  0.006544 -0.006544
# 2010-01-12  1.4494 -0.001310         -1  0.006984  0.006544
# 2010-01-13  1.4510  0.001103          1 -0.001310  0.006984

# %% [markdown]
# ## 聚类分析
# - 1.对特征数据进行聚类操作，使用Kmeans,K=2来完成
# - 2.将聚类结果划分成-1,1两种类别
# - 3.试试水，看看效果

# %%
from sklearn.cluster import KMeans

# %%
model = KMeans(n_clusters=2, random_state=0)  #  <1>

# %%
model.fit(data[cols])
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=2, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=0, tol=0.0001, verbose=0)

# %%
data['pos_clus'] = model.predict(data[cols])

# %%
data['pos_clus'] = np.where(data['pos_clus'] == 1, -1, 1)

# %%
data['pos_clus'].values
# Out:
# array([-1,  1, -1, ...,  1,  1, -1])

# %%
plt.figure(figsize=(10, 6))
plt.scatter(data[cols].iloc[:, 0], data[cols].iloc[:, 1],
            c=data['pos_clus'], cmap='coolwarm');

# %%
data['strat_clus'] = data['pos_clus'] * data['returns']

# %%
data[['returns', 'strat_clus']].sum().apply(np.exp)
# Out:
# returns       0.810644
# strat_clus    1.174783
# dtype: float64

# %%
(data['direction'] == data['pos_clus']).value_counts()
# Out:
# True     1071
# False    1064
# dtype: int64

# %%
data[['returns', 'strat_clus']].cumsum().apply(np.exp).plot(figsize=(10, 6));
# plt.savefig('../../images/ch15/strat_ml_05.png');

# %% [markdown]
# ## 统计分析
# - 1.分别统计前两天，前一天的数据情况，并将结果划分成两个区间
# - 2.使用groupby来观察分组情况
# - 3.设计策略；来试试水

# %%
def create_bins(data, bins=[0]):
    global cols_bin
    cols_bin = []
    for col in cols:
        col_bin = col + '_bin'
        data[col_bin] = np.digitize(data[col], bins=bins)  
        cols_bin.append(col_bin)

# %%
create_bins(data)

# %%
data[cols_bin + ['direction']].head()
# Out:
#             lag_1_bin  lag_2_bin  direction
# Date
# 2010-01-07          1          0         -1
# 2010-01-08          0          1          1
# 2010-01-11          1          0          1
# 2010-01-12          1          1         -1
# 2010-01-13          0          1          1

# %%
grouped = data.groupby(cols_bin + ['direction'])
grouped.size()
# Out:
# lag_1_bin  lag_2_bin  direction
# 0          0          -1           239
#                        0             4
#                        1           258
#            1          -1           262
#                        1           288
# 1          0          -1           272
#                        0             1
#                        1           278
#            1          -1           278
#                        0             4
#                        1           251
# dtype: int64

# %%
res = grouped['direction'].size().unstack(fill_value=0)

# %%
def highlight_max(s):
    is_max = s == s.max()
    return ['background-color: yellow' if v else '' for v in is_max]

# %%
res.style.apply(highlight_max, axis=1)
# Out:
# <style  type="text/css" >
#     #T_ed2d47a8_5ba1_11ea_aa80_309c2367eff2row0_col2 {
#             background-color:  yellow;
#         }    #T_ed2d47a8_5ba1_11ea_aa80_309c2367eff2row1_col2 {
#             background-color:  yellow;
#         }    #T_ed2d47a8_5ba1_11ea_aa80_309c2367eff2row2_col2 {
#             background-color:  yellow;
#         }    #T_ed2d47a8_5ba1_11ea_aa80_309c2367eff2row3_col0 {
#             background-color:  yellow;
#         }</style>
# <table id="T_ed2d47a8_5ba1_11ea_aa80_309c2367eff2" >
# <thead>    <tr>
#         <th class="blank" ></th>
#         <th class="index_name level0" >direction</th>
#         <th class="col_heading level0 col0" >-1</th>
#         <th class="col_heading level0 col1" >0</th>
#         <th class="col_heading level0 col2" >1</th>
#     </tr>    <tr>
#         <th class="index_name level0" >lag_1_bin</th>
#         <th class="index_name level1" >lag_2_bin</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_ed2d47a8_5ba1_11ea_aa80_309c2367eff2level0_row0" class="row_heading level0 row0" rowspan=2>0</th>
#         <th id="T_ed2d47a8_5ba1_11ea_aa80_309c2367eff2level1_row0" class="row_heading level1 row0" >0</th>
#         <td id="T_ed2d47a8_5ba1_11ea_aa80_309c2367eff2row0_col0" class="data row0 col0" >239</td>
#         <td id="T_ed2d47a8_5ba1_11ea_aa80_309c2367eff2row0_col1" class="data row0 col1" >4</td>
#         <td id="T_ed2d47a8_5ba1_11ea_aa80_309c2367eff2row0_col2" class="data row0 col2" >258</td>
#     </tr>    <tr>
#         <th id="T_ed2d47a8_5ba1_11ea_aa80_309c2367eff2level1_row1" class="row_heading level1 row1" >1</th>
#         <td id="T_ed2d47a8_5ba1_11ea_aa80_309c2367eff2row1_col0" class="data row1 col0" >262</td>
#         <td id="T_ed2d47a8_5ba1_11ea_aa80_309c2367eff2row1_col1" class="data row1 col1" >0</td>
#         <td id="T_ed2d47a8_5ba1_11ea_aa80_309c2367eff2row1_col2" class="data row1 col2" >288</td>
#     </tr>    <tr>
#         <th id="T_ed2d47a8_5ba1_11ea_aa80_309c2367eff2level0_row2" class="row_heading level0 row2" rowspan=2>1</th>
#         <th id="T_ed2d47a8_5ba1_11ea_aa80_309c2367eff2level1_row2" class="row_heading level1 row2" >0</th>
#         <td id="T_ed2d47a8_5ba1_11ea_aa80_309c2367eff2row2_col0" class="data row2 col0" >272</td>
#         <td id="T_ed2d47a8_5ba1_11ea_aa80_309c2367eff2row2_col1" class="data row2 col1" >1</td>
#         <td id="T_ed2d47a8_5ba1_11ea_aa80_309c2367eff2row2_col2" class="data row2 col2" >278</td>
#     </tr>    <tr>
#         <th id="T_ed2d47a8_5ba1_11ea_aa80_309c2367eff2level1_row3" class="row_heading level1 row3" >1</th>
#         <td id="T_ed2d47a8_5ba1_11ea_aa80_309c2367eff2row3_col0" class="data row3 col0" >278</td>
#         <td id="T_ed2d47a8_5ba1_11ea_aa80_309c2367eff2row3_col1" class="data row3 col1" >4</td>
#         <td id="T_ed2d47a8_5ba1_11ea_aa80_309c2367eff2row3_col2" class="data row3 col2" >251</td>
#     </tr></tbody>
# </table>

# %%
data['pos_freq'] = np.where(data[cols_bin].sum(axis=1) == 2, -1, 1)

# %%
(data['direction'] == data['pos_freq']).value_counts()
# Out:
# True     1102
# False    1033
# dtype: int64

# %%
data['strat_freq'] = data['pos_freq'] * data['returns']

# %%
data[['returns', 'strat_freq']].sum().apply(np.exp)
# Out:
# returns       0.810644
# strat_freq    0.989513
# dtype: float64

# %%
data[['returns', 'strat_freq']].cumsum().apply(np.exp).plot(figsize=(10, 6));
# plt.savefig('../../images/ch15/strat_ml_06.png');
